# %%
import json
import requests 
import streamlit as st
API_KEY="6a4b3c928751d3a5640787f17d805d62"
city_name="Lahore"
url=f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_KEY}&units=metric"
def get_weather(city_name):
    Response=requests.get(url)
    if Response.status_code==200:
        Data=Response.json()
        print(json.dumps(Data, indent=4))
get_weather("city_name")
# Out:
# {
#     "coord": {
#         "lon": 74.3436,
#         "lat": 31.5497
#     },
#     "weather": [
#         {
#             "id": 711,
#             "main": "Smoke",
#             "description": "smoke",
#             "icon": "50n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 28.99,
#         "feels_like": 29.77,
#         "temp_min": 28.99,
#         "temp_max": 28.99,
#         "pressure": 1004,
#         "humidity": 51,
#         "sea_level": 1004,
#         "grnd_level": 980
#     },
#     "visibility": 4000,
#     "wind": {
#         "speed": 1.54,
#         "deg": 60
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1745175434,
#     "sys": {
#         "type": 1,
#         "id": 7585,
#         "country": "PK",
#         "sunrise": 1745108917,
#         "sunset": 1745156046
#     },
#     "timezone": 18000,
#     "id": 1172451,
#     "name": "Lahore",
#     "cod": 200
# }

# %%
import json
import requests 
import streamlit as st
API_KEY="072b4d8a14063fe8befc4835933fcbfc"
city_name="Lahore"
url=f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_KEY}&units=metric"
def get_weather(city_name):
    Response=requests.get(url)
    if Response.status_code==200:
        Data=Response.json()
        weather={
            "Cty Name ":Data["name"],
            "Weather ":Data["weather"]["description"],
            "Temperature(C) ":Data["main"]["temp"],
            "Humidity ":Data["main"]["humidity"],
            "Pressure(hpa) ":Data["main"]["pressure"],
            "Wind Speed ":Data["wind"]["speed"],
            "Feels Like": Data["main"]["feels_like"]
        }
        return get_weather
    else:
        return None
st.title("🌤️ Weather Forecast App")  
st.markdown("Get real-time weather updates from any city")
city_name=st.text_input("Enter city Name: ")
if city_name:
    weather_data=get_weather(city_name)
    if weather_data:
        st.success(f"Weather in {weather_data["City Name"]}")
        st.metric(f"Temperatue(C) {weather_data["Temperature(C)"]}")
        st.write(f"Weather {weather_data["Weather"]}")
        st.write(f"Humidity{weather_data["Humidity"]}")
        st.write(f"Pressure{weather_data["Pressure(hpa)"]}")
        st.write(f"Wind Flow{weather_data["Wind Speed"]}")
        st.write(f"Feels Like{weather_data["Feels Like"]}")
    else:
        st.error("City Not Found")
 #Inject CSS
def local_css(file_name):
    with open("style.css") as f:
        st.markdown(f"<style>{f.read()}</style>", unsafe_allow_html=True)

# Call the function with the filename as a string
local_css("style.css")

response.status_code
# Out:
# 2025-04-24 07:34:45.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 07:34:45.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import json
import requests 
import streamlit as st

# Your OpenWeather API key
API_KEY = "6a4b3c928751d3a5640787f17d805d62"

# Function to get weather data
def get_weather(city_name):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_KEY}&units=metric"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        weather = {
            "City Name": data["name"],
            "Weather": data["weather"][0]["description"].title(),  # use [0] because it's a list
            "Temperature(C)": data["main"]["temp"],
            "Humidity": data["main"]["humidity"],
            "Pressure(hpa)": data["main"]["pressure"],
            "Wind Speed": data["wind"]["speed"],
            "Feels Like": data["main"]["feels_like"]
        }
        return weather
    else:
        return None

# Streamlit UI
st.markdown(
    "<h1 style='color:black; font-size: 36px;'>🌤️ Weather Forecast App</h1>",
    unsafe_allow_html=True
)

st.markdown(
    "<p style='color:black; font-size:18px;'>Get real-time weather updates from any city</p>",
    unsafe_allow_html=True
)

# Take user input
city_name = st.text_input("Enter City Name:")

# Show result if user enters a city
if city_name:
    weather_data = get_weather(city_name)

    if weather_data:
        st.success(f"Weather in {weather_data['City Name']}")
        st.metric("Temperature (C)", f"{weather_data['Temperature(C)']} °C")
        st.write(f"**Weather:** {weather_data['Weather']}")
        st.write(f"**Humidity:** {weather_data['Humidity']}%")
        st.write(f"**Pressure:** {weather_data['Pressure(hpa)']} hPa")
        st.write(f"**Wind Speed:** {weather_data['Wind Speed']} m/s")
        st.write(f"**Feels Like:** {weather_data['Feels Like']} °C")
    else:
        st.error("City not found. Please try again.") 
           
def local_css(file_name):
    with open("style.css") as f:
        st.markdown(f"<style>{f.read()}</style>", unsafe_allow_html=True)
# Out:
# 2025-04-24 08:08:36.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 08:08:36.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
city_name="Lahore"
forecast_url = f"https://api.openweathermap.org/data/2.5/forecast?q={city_name}&appid={API_KEY}&units=metric"
response=requests.get(forecast_url)
if response.status_code==200:
    data=response.json()
# Out:
# 200

# %%
import streamlit as st
import requests
import datetime
from collections import defaultdict

API_KEY = "6a4b3c928751d3a5640787f17d805d62"  # Replace with your real API key

st.title("🌦️ 5-Day Weather Forecast")
city_name = st.text_input("Enter City Name")

if city_name:
    forecast_url = f"https://api.openweathermap.org/data/2.5/forecast?q={city_name}&appid={API_KEY}&units=metric"
    response = requests.get(forecast_url)
    if response.status_code==200:
        data = response.json()
        

    if "list" in data:
        st.subheader(f"📍 Forecast for {data['city']['name']}, {data['city']['country']}")
        
        # Group forecast data by date
        forecast_by_date = defaultdict(list)
        for entry in data["list"]:
            date = entry["dt_txt"].split(" ")[0]
            forecast_by_date[date].append(entry)

        # Show forecasts per day
        for date, entries in forecast_by_date.items():
            st.markdown(f"### 📅 {date}")
            for entry in entries:
                time = entry["dt_txt"].split(" ")[1][:5]
                temp = entry["main"]["temp"]
                weather = entry["weather"][0]["description"].title()
                wind = entry["wind"]["speed"]
                st.write(f"🕒 {time} | 🌡️ {temp}°C | 🌥️ {weather} | 💨 Wind: {wind} m/s")
            st.markdown("---")
    else:
        st.error("Could not fetch forecast data.")
import matplotlib.pyplot as plt
import numpy as np

# Function to plot hourly forecast
def plot_hourly_forecast(data):
    # Extract hours and temperatures
    hours = [entry["dt_txt"].split(" ")[1][:5] for entry in data["list"]]
    temps = [entry["main"]["temp"] for entry in data["list"]]
    
    # Plot the data
    plt.figure(figsize=(10, 6))
    plt.plot(hours, temps, marker='o', color='tab:blue')
    plt.title('Hourly Temperature Forecast')
    plt.xlabel('Hour of Day')
    plt.ylabel('Temperature (°C)')
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Display the plot
    st.pyplot(plt)
# Out:
# 2025-04-25 05:16:01.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-25 05:16:01.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
